# %% [markdown]
# # SRC004 safe fixture
#
# Synthetic NoFutureData notebook conformance fixture.

# %%
out = left.merge_asof(right, on='ts', direction='backward')
